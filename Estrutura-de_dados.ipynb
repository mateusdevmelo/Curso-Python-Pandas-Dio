# %%
# **Curso Python Para Análise de dados** - *Fernanda Santos*

# %%
# **Estrutura de dados**

# %%
## **Listas**

# %%
#Criando uma lista chamada carros

# %%
carros = [1,2,3]
carros
# Out:
# [1, 2, 3]

# %%
carros = ["camaro", "ronda", 12345, 6.5]
carros
# Out:
# ['camaro', 'ronda', 12345, 6.5]

# %%
#Imprimindo o primeiro elemento da lista

# %%
carros[0]
# Out:
# 'camaro'

# %%
#Imprimindo o 4 elemento da lista

# %%
carros[3]
# Out:
# 6.5

# %%
#Substituindo o primeiro elemento da lista

# %%
carros[0] = "uno"

# %%
carros
# Out:
# ['uno', 'ronda', 12345, 6.5]

# %%
#Removendo gato da lista
carros.remove("uno")

# %%
carros
# Out:
# ['ronda', 12345, 6.5]

# %%
len(carros)
# Out:
# 3

# %%
"uno" in carros
# Out:
# False

# %%
lista = [700, 20, 200, 80, 5]

# %%
max(lista)
# Out:
# 700

# %%
min(lista)
# Out:
# 5

# %%
carros.append(["v8","fusca"])

# %%
carros
# Out:
# ['ronda', 12345, 6.5, ['v8', 'fusca']]

# %%
carros.extend(["camarox",7])

# %%
carros
# Out:
# ['ronda', 12345, 6.5, ['v8', 'fusca'], 'camarox', 7]

# %%
carros.count("v8")
# Out:
# 0

# %%
lista.sort()

# %%
lista
# Out:
# [5, 20, 80, 200, 700]

# %%
# **Tuplas**

# %%
#As tuplas usam parênteses como sintaxe
tp = ("v9","combi",200,60)

# %%
#Retornando o primeiro elemento
tp[0]
# Out:
# 'v9'

# %%
#Diferente das listas as tuplas são imutáveis, o que quer dizer que não podemos alterar os seus elementos
tp[0] = "v10"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-8ea9b778bbb7> in <module>
#       1 #Diferente das listas as tuplas são imutáveis, o que quer dizer que não podemos alterar os seus elementos
# ----> 2 tp[0] = "v10"
#
# TypeError: 'tuple' object does not support item assignment

# %%
tp.count("v10")
# Out:
# 0

# %%
tp[0:2]
# Out:
# ('v9', 'combi')

# %%
# **Dicionários**

# %%
#Para criar um dicionário utilizamos as {}
dc = {"Vctra":20, "Bmw":10, "Jaguar":15, "Uno2":5} #Dicionários trabalham com o condeito chave e valor

# %%
#Acessando o valor de um dicionário através da chave
dc['Bmw']
# Out:
# 10

# %%
#Atualizando o valor da Maçã
dc['Bmw'] = 24

# %%
dc
# Out:
# {'Vctra': 20, 'Bmw': 24, 'Jaguar': 15, 'Uno2': 5}

# %%
#Retornando todas as chaves do dicionário
dc.keys()
# Out:
# dict_keys(['Vctra', 'Bmw', 'Jaguar', 'Uno2'])

# %%
#Retornando os valores do dicionário
dc.values()
# Out:
# dict_values([20, 24, 15, 5])

# %%
#Verificando se já existe uma chave no dicionário e caso não exista inserir
dc.setdefault("dc",23)
# Out:
# 23

# %%
dc
# Out:
# {'Vctra': 20, 'Bmw': 24, 'Jaguar': 15, 'Uno2': 5, 'dc': 23}
