# %%
# Ola mundo Python

# %%
print("Olá Mundo")
# Out:
# Olá Mundo

# %%
print("Estou aprendendo Python")
# Out:
# Estou aprendendo Python

# %%
#Esse é um comentário em Python

# %%
#Multiplicação
3 * 3
# Out:
# 9

# %%
#Divisão
45/6
# Out:
# 7.5

# %%
# Declarando variaveis e atribuindo valores

a = 6
b = 5

# %%
# somando as variaveis

# %%
a + b
# Out:
# 11

# %%
#Criando uma variável do tipo string
frase = "Python para análise de dados Professora Fernanda"

# %%
frase[5]
# Out:
# 'n'

# %%
frase[0:12]
# Out:
# 'Python para '

# %%
frase[12:]
# Out:
# 'análise de dados Professora Fernanda'

# %%
frase[17]
# Out:
# 's'

# %%
frase.count("dados")
# Out:
# 1

# %%
frase.lower()
# Out:
# 'python para análise de dados professora fernanda'

# %%
frase = frase.upper()

# %%
frase.replace("Python","Frases")
# Out:
# 'PYTHON PARA ANÁLISE DE DADOS PROFESSORA FERNANDA'
